# %% [markdown]
# # Install Library

# %%
# %pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (2.15.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (2.0.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.18.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: filelock in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.18.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.18.0->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->datasets) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (4.36.0)
# Requirement already satisfied: filelock in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: colorama in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from requests->transformers) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (0.1.99)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipywidgets) (0.1.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipywidgets) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\ihlas\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in c:\users\ihlas\appdata\roaming\python\python310\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Load Data dan Model

# %% [markdown]
# ## Load Data dari Hugging Face

# %%
from datasets import load_dataset
import pandas as pd

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Datasets Tunggal

# %% [markdown]
# ### Wiki-Label Datasets

# %%
# If the dataset is gated/private, make sure you have run huggingface-cli login
wiki_dataset = load_dataset("NicolaiSivesind/human-vs-machine", "wiki_labeled")

wiki_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'label', 'text', 'word_count'],
#         num_rows: 210000
#     })
#     test: Dataset({
#         features: ['title', 'label', 'text', 'word_count'],
#         num_rows: 45000
#     })
#     validation: Dataset({
#         features: ['title', 'label', 'text', 'word_count'],
#         num_rows: 45000
#     })
# })

# %%
# Konversi dataset ke DataFrame Pandas
train_wiki_df = wiki_dataset["train"].to_pandas()
test_wiki_df = wiki_dataset["test"].to_pandas()
val_wiki_df = wiki_dataset["validation"].to_pandas()

# %%
print(f"Ukuran Train Wiki-Label: {train_wiki_df.shape}")
print(f"Ukuran Test Wiki-Label: {test_wiki_df.shape}")
print(f"Ukuran Val Wiki-Label: {val_wiki_df.shape}")
# Out:
# Ukuran Train Wiki-Label: (210000, 4)
# Ukuran Test Wiki-Label: (45000, 4)
# Ukuran Val Wiki-Label: (45000, 4)

# %%
train_wiki_df
# Out:
#                              title  label
# 0                     James Scobie      0  \
# 1                     James Scobie      1
# 2                     Dagliç sheep      0
# 3                     Dagliç sheep      1
# 4                    Hamdard India      0
# ...                            ...    ...
# 209995  Esperanza mía (soundtrack)      1
# 209996    Macquarie Street, Hobart      0
# 209997    Macquarie Street, Hobart      1
# 209998              Daniel L. Ryan      0
# 209999              Daniel L. Ryan      1
#
#                                                      text  word_count
# 0       James Scobie (29 November 1826 – 7 October 185...         175
# 1       James Scobie (29 November 1826 – 7 October 189...         242
# 2       The Dagliç is a breed of sheep found primarily...         152
# 3       The Dagliç is a breed of sheep that is found i...          33
# 4       Hamdard Laboratories (India), is a Unani pharm...         160
# ...                                                   ...         ...
# 209995  Esperanza mía is the official soundtrack of th...         136
# 209996  Macquarie Street a major one way street passin...         175
# 209997  Macquarie Street a major one way street in Hob...         113
# 209998  Daniel Leo Ryan (September 28, 1930 – December...         189
# 209999  Daniel Leo Ryan (September 28, 1930 – February...         146
#
# [210000 rows x 4 columns]

# %% [markdown]
# ### Research-Abstract-Label Datasets

# %%
# If the dataset is gated/private, make sure you have run huggingface-cli login
abstract_dataset = load_dataset("NicolaiSivesind/human-vs-machine", "research_abstracts_labeled")

abstract_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'label', 'text', 'word_count'],
#         num_rows: 14000
#     })
#     test: Dataset({
#         features: ['title', 'label', 'text', 'word_count'],
#         num_rows: 3000
#     })
#     validation: Dataset({
#         features: ['title', 'label', 'text', 'word_count'],
#         num_rows: 3000
#     })
# })

# %%
# Konversi dataset ke DataFrame Pandas
train_abstract_df = abstract_dataset["train"].to_pandas()
test_abstract_df = abstract_dataset["test"].to_pandas()
val_abstract_df = abstract_dataset["validation"].to_pandas()

# %%
print(f"Ukuran Train abstract-Label: {train_abstract_df.shape}")
print(f"Ukuran Test abstract-Label: {test_abstract_df.shape}")
print(f"Ukuran Val abstract-Label: {val_abstract_df.shape}")
# Out:
# Ukuran Train abstract-Label: (14000, 4)
# Ukuran Test abstract-Label: (3000, 4)
# Ukuran Val abstract-Label: (3000, 4)

# %%
train_abstract_df
# Out:
#                                                    title  label
# 0      Study of coupling loss on bi-columnar BSCCO/Ag...      0  \
# 1      Study of coupling loss on bi-columnar BSCCO/Ag...      1
# 2      Weighted Solyanik estimates for the strong max...      0
# 3      Weighted Solyanik estimates for the strong max...      1
# 4      SOFIA-EXES Observations of Betelgeuse during t...      0
# ...                                                  ...    ...
# 13995  Effects of bonding type and interface geometry...      1
# 13996  GOODS-Herschel: The far-infrared view of star ...      0
# 13997  GOODS-Herschel: The far-infrared view of star ...      1
# 13998  Single-qubit peration sharing with Bell and W ...      0
# 13999  Single-qubit peration sharing with Bell and W ...      1
#
#                                                     text  word_count
# 0      Coupling losses were studied in composite tape...         280
# 1      In this study, we investigate the coupling los...         215
# 2      Let $\mathsf M_{\mathsf S}$ denote the strong ...         332
# 3      In this paper, we investigate Weighted Solyani...         225
# 4      In 2019 October Betelgeuse began a decline in ...         268
# ...                                                  ...         ...
# 13995  The coherent transport of magnetic information...         286
# 13996  We present a study of the infrared properties ...         330
# 13997  This paper presents the results of a study of ...         339
# 13998  Two tripartite schemes are put forward with sh...          98
# 13999  In quantum computing, sharing single-qubit ope...          95
#
# [14000 rows x 4 columns]

# %% [markdown]
# ## Datasets Gabungan

# %% [markdown]
# ### Datasets Gabungan Full

# %%
train_group_all_df = pd.concat([train_wiki_df, train_abstract_df]).reset_index(drop=True)
val_group_all_df = pd.concat([val_wiki_df, val_abstract_df]).reset_index(drop=True)
test_group_all_df = pd.concat([test_wiki_df, test_abstract_df]).reset_index(drop=True)

# %%
print(f"Ukuran Train abstract-Label: {train_group_all_df.shape}")
print(f"Ukuran Test abstract-Label: {val_group_all_df.shape}")
print(f"Ukuran Val abstract-Label: {test_group_all_df.shape}")
# Out:
# Ukuran Train abstract-Label: (224000, 4)
# Ukuran Test abstract-Label: (48000, 4)
# Ukuran Val abstract-Label: (48000, 4)

# %%
train_group_all_df
# Out:
#                                                     title  label
# 0                                            James Scobie      0  \
# 1                                            James Scobie      1
# 2                                            Dagliç sheep      0
# 3                                            Dagliç sheep      1
# 4                                           Hamdard India      0
# ...                                                   ...    ...
# 223995  Effects of bonding type and interface geometry...      1
# 223996  GOODS-Herschel: The far-infrared view of star ...      0
# 223997  GOODS-Herschel: The far-infrared view of star ...      1
# 223998  Single-qubit peration sharing with Bell and W ...      0
# 223999  Single-qubit peration sharing with Bell and W ...      1
#
#                                                      text  word_count
# 0       James Scobie (29 November 1826 – 7 October 185...         175
# 1       James Scobie (29 November 1826 – 7 October 189...         242
# 2       The Dagliç is a breed of sheep found primarily...         152
# 3       The Dagliç is a breed of sheep that is found i...          33
# 4       Hamdard Laboratories (India), is a Unani pharm...         160
# ...                                                   ...         ...
# 223995  The coherent transport of magnetic information...         286
# 223996  We present a study of the infrared properties ...         330
# 223997  This paper presents the results of a study of ...         339
# 223998  Two tripartite schemes are put forward with sh...          98
# 223999  In quantum computing, sharing single-qubit ope...          95
#
# [224000 rows x 4 columns]

# %% [markdown]
# ### Datasets Gabungan Balance

# %%
train_group_balance_df = pd.concat([train_wiki_df.iloc[:14000], train_abstract_df]).reset_index(drop=True)
val_group_balance_df = pd.concat([val_wiki_df.iloc[:3000], val_abstract_df]).reset_index(drop=True)
test_group_balance_df = pd.concat([test_wiki_df.iloc[:3000], test_abstract_df]).reset_index(drop=True)

# %%
print(f"Ukuran Train abstract-Label: {train_group_balance_df.shape}")
print(f"Ukuran Test abstract-Label: {val_group_balance_df.shape}")
print(f"Ukuran Val abstract-Label: {test_group_balance_df.shape}")
# Out:
# Ukuran Train abstract-Label: (28000, 4)
# Ukuran Test abstract-Label: (6000, 4)
# Ukuran Val abstract-Label: (6000, 4)

# %%
train_group_balance_df
# Out:
#                                                    title  label
# 0                                           James Scobie      0  \
# 1                                           James Scobie      1
# 2                                           Dagliç sheep      0
# 3                                           Dagliç sheep      1
# 4                                          Hamdard India      0
# ...                                                  ...    ...
# 27995  Effects of bonding type and interface geometry...      1
# 27996  GOODS-Herschel: The far-infrared view of star ...      0
# 27997  GOODS-Herschel: The far-infrared view of star ...      1
# 27998  Single-qubit peration sharing with Bell and W ...      0
# 27999  Single-qubit peration sharing with Bell and W ...      1
#
#                                                     text  word_count
# 0      James Scobie (29 November 1826 – 7 October 185...         175
# 1      James Scobie (29 November 1826 – 7 October 189...         242
# 2      The Dagliç is a breed of sheep found primarily...         152
# 3      The Dagliç is a breed of sheep that is found i...          33
# 4      Hamdard Laboratories (India), is a Unani pharm...         160
# ...                                                  ...         ...
# 27995  The coherent transport of magnetic information...         286
# 27996  We present a study of the infrared properties ...         330
# 27997  This paper presents the results of a study of ...         339
# 27998  Two tripartite schemes are put forward with sh...          98
# 27999  In quantum computing, sharing single-qubit ope...          95
#
# [28000 rows x 4 columns]

# %% [markdown]
# # Test Sampel 10 Data

# %%
sampel_train = train_wiki_df.loc[0:9]
sampel_train
# Out:
#                      title  label
# 0             James Scobie      0  \
# 1             James Scobie      1
# 2             Dagliç sheep      0
# 3             Dagliç sheep      1
# 4            Hamdard India      0
# 5            Hamdard India      1
# 6  Berkeley Public Library      0
# 7  Berkeley Public Library      1
# 8                     Såne      0
# 9                     Såne      1
#
#                                                 text  word_count
# 0  James Scobie (29 November 1826 – 7 October 185...         175
# 1  James Scobie (29 November 1826 – 7 October 189...         242
# 2  The Dagliç is a breed of sheep found primarily...         152
# 3  The Dagliç is a breed of sheep that is found i...          33
# 4  Hamdard Laboratories (India), is a Unani pharm...         160
# 5  Hamdard Laboratories (India), is a Unani pharm...         125
# 6  The Berkeley Public Library is the public libr...         164
# 7  The Berkeley Public Library is the public libr...          92
# 8  The Såne-sheep is a breed of Danish origin. In...         223
# 9  The Såne-sheep is a breed of Danish sheep that...          71

# %%
sampel_test = test_wiki_df.loc[0:9]
sampel_test
# Out:
#                 title  label
# 0  Jum Jainudin Akbar      0  \
# 1  Jum Jainudin Akbar      1
# 2     Daphne Oxenford      0
# 3     Daphne Oxenford      1
# 4      MAX Light Rail      0
# 5      MAX Light Rail      1
# 6        Giulio Zardo      0
# 7        Giulio Zardo      1
# 8  Artashes Shahinian      0
# 9  Artashes Shahinian      1
#
#                                                 text  word_count
# 0  Jum Jainudin Akbar (3 September 1963 – 11 Nove...         185
# 1  Jum Jainudin Akbar (3 September 1963 – 18 Nove...         168
# 2  Daphne Margaret du Grivel Oxenford (31 October...         181
# 3  Daphne Margaret du Grivel Oxenford (31 October...         142
# 4  MAX Light Rail (for Metropolitan Area Express)...         264
# 5  MAX Light Rail (for Metropolitan Area Express)...         209
# 6  Giulio Zardo (born July 14, 1980 in Montreal, ...         178
# 7  Giulio Zardo (born July 14, 1980 in Milan) is ...          80
# 8  Artashes Shahinyan (, December 19, 1906 – May ...         241
# 9  Artashes Shahinyan (, December 19, 1906 – June...         219

# %%
sampel_val = val_wiki_df.loc[0:9]
sampel_val
# Out:
#                 title  label
# 0  Morgan (2012 film)      0  \
# 1  Morgan (2012 film)      1
# 2             Lachung      0
# 3             Lachung      1
# 4  Fountain (Duchamp)      0
# 5  Fountain (Duchamp)      1
# 6          Spiro Crne      0
# 7          Spiro Crne      1
# 8      Anthony Wilden      0
# 9      Anthony Wilden      1
#
#                                                 text  word_count
# 0  Morgan is a 2012 gay film directed by Michael ...         154
# 1  Morgan is a 2012 gay film directed by Tom McCa...          73
# 2  Lachung is a town and hill station in northeas...         193
# 3  Lachung is a town and hill station in the stat...          40
# 4  Fountain is a readymade sculpture by Marcel Du...         247
# 5  Fountain is a readymade sculpture by Marcel Du...         221
# 6  Spiro Crne (; died 22 April 1881) was a rebel ...         341
# 7  Spiro Crne (; died 22 April 1881) was a Serbia...         124
# 8  Anthony George Wilden (14 December 1935 – 29 D...         166
# 9  Anthony George Wilden (14 December 1935 – 21 O...         209

# %% [markdown]
# # Load Model

# %% [markdown]
# ### XLNet

# %%
import tensorflow as tf
import numpy as np

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve

# %%
from transformers import TFXLNetModel, XLNetTokenizer

# %%
xlnet_model = 'xlnet-base-cased'
xlnet_tokenizer = XLNetTokenizer.from_pretrained(xlnet_model)

# %%
number_of_classes = 1 #len(names)
number_of_classes
# Out:
# 1

# %%
def create_xlnet(mname):
    """ Creates the model. It is composed of the XLNet main block and then
    a classification head its added
    """
    # Define token ids as inputs
    word_inputs = tf.keras.Input(shape=(120,), name='word_inputs', dtype='int32')

    # Call XLNet model
    xlnet = TFXLNetModel.from_pretrained(mname)
    xlnet_encodings = xlnet(word_inputs)[0]

    # CLASSIFICATION HEAD 
    # Collect last step from last hidden state (CLS)
    doc_encoding = tf.squeeze(xlnet_encodings[:, -1:, :], axis=1)
    # Apply dropout for regularization
    doc_encoding = tf.keras.layers.Dropout(.1)(doc_encoding)
    # Final output 
    outputs = tf.keras.layers.Dense(number_of_classes, activation='sigmoid', name='outputs')(doc_encoding)

    # Compile model
    model = tf.keras.Model(inputs=[word_inputs], outputs=[outputs])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5), loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
    
    return model

# %%
xlnet = create_xlnet(xlnet_model)
# Out:
# C:\Users\ihlas\AppData\Roaming\Python\Python310\site-packages\keras\initializers\initializers.py:120: UserWarning: The initializer TruncatedNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Some layers from the model checkpoint at xlnet-base-cased were not used when initializing TFXLNetModel: ['lm_loss']
# - This IS expected if you are initializing TFXLNetModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFXLNetModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFXLNetModel were initialized from the model checkpoint at xlnet-base-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFXLNetModel for predictions without further training.

# %%
xlnet.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  word_inputs (InputLayer)    [(None, 120)]             0
#
#  tfxl_net_model (TFXLNetMode  TFXLNetModelOutput(last_  116718336
#  l)                          hidden_state=(None, 120,
#                               768),
#                               mems=((120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768),
#                               (120, None, 768)),
#                               hidden_states=None, att
#                              entions=None)
#
#  tf.__operators__.getitem (S  (None, 1, 768)           0
#  licingOpLambda)
#
#  tf.compat.v1.squeeze (TFOpL  (None, 768)              0
#  ambda)
#
#  dropout_37 (Dropout)        (None, 768)               0
#
#  outputs (Dense)             (None, 1)                 769
#
# =================================================================
# Total params: 116,719,105
# Trainable params: 116,719,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_abstract_df['label'].value_counts()
# Out:
# label
# 0    7000
# 1    7000
# Name: count, dtype: int64

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
y = le.fit_transform(train_abstract_df['label'])

# %%
text = train_abstract_df['text']
labels = train_abstract_df['label']

# %%
def get_inputs(text, tokenizer, max_len=120):
    """ Gets tensors from text using the tokenizer provided"""
    inps = [tokenizer.encode_plus(t, max_length=max_len, pad_to_max_length=True, add_special_tokens=True) for t in text]
    inp_tok = np.array([a['input_ids'] for a in inps])
    ids = np.array([a['attention_mask'] for a in inps])
    segments = np.array([a['token_type_ids'] for a in inps])
    return inp_tok, ids, segments

# %%
def warmup(epoch, lr):
    """Used for increasing the learning rate slowly, this tends to achieve better convergence.
    However, as we are finetuning for few epoch it's not crucial.
    """
    return max(lr +1e-6, 2e-5)

def plot_metrics(pred, true_labels):
    """Plots a ROC curve with the accuracy and the AUC"""
    acc = accuracy_score(true_labels, np.array(pred.flatten() >= .5, dtype='int'))
    fpr, tpr, thresholds = roc_curve(true_labels, pred)
    auc = roc_auc_score(true_labels, pred)

    fig, ax = plt.subplots(1, figsize=(8,8))
    ax.plot(fpr, tpr, color='red')
    ax.plot([0,1], [0,1], color='black', linestyle='--')
    ax.set_title(f"AUC: {auc}\nACC: {acc}");
    return fig

# %%
inp_tok, ids, segments = get_inputs(text, xlnet_tokenizer)
# Out:
# c:\Users\ihlas\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:2618: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=4, min_delta=0.02, restore_best_weights=True),
    tf.keras.callbacks.LearningRateScheduler(warmup, verbose=0),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=1e-6, patience=2, verbose=0, mode='auto', min_delta=0.001, cooldown=0, min_lr=1e-6)
]

# %%
inp_tok.shape
# Out:
# (14000, 120)

# %%
hist = xlnet.fit(x=inp_tok, y=labels, epochs=2, batch_size=32, validation_split=.15, callbacks=callbacks)
# Out:
# Epoch 1/2
#  31/372 [=>............................] - ETA: 19:10:05 - loss: 0.4765 - accuracy: 0.7923 - precision: 0.7907 - recall: 0.7775

# %% [markdown]
# ### T5

# %% [markdown]
# ### ERNIE
